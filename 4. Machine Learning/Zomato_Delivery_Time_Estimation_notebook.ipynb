# %%
import pandas as pd
df = pd.read_csv("/content/zomato_data.csv")
df
# Out:
#        distance_km  restaurant_rating weather time_of_day  \
# 0             5.93                4.5  cloudy        peak
# 1            14.29                2.9   rainy        peak
# 2            11.11                4.9   sunny    off-peak
# 3             9.18                4.6  cloudy        peak
# 4             2.76                4.8   rainy    off-peak
# ...            ...                ...     ...         ...
# 79995         5.17                4.4   sunny    off-peak
# 79996         5.93                4.0   rainy        peak
# 79997         6.03                3.2   sunny    off-peak
# 79998         2.38                4.5   rainy        peak
# 79999        14.24                3.6   sunny        peak
#
#        delivery_speed_kmph  active_orders_queue  restaurant_prep_time_min  \
# 0                    15.07                   14                        18
# 1                    21.00                   17                        36
# ...

# %%
df.head()
# Out:
#    distance_km  restaurant_rating weather time_of_day  delivery_speed_kmph  \
# 0         5.93                4.5  cloudy        peak                15.07
# 1        14.29                2.9   rainy        peak                21.00
# 2        11.11                4.9   sunny    off-peak                30.16
# 3         9.18                4.6  cloudy        peak                21.84
# 4         2.76                4.8   rainy    off-peak                36.26
#
#    active_orders_queue  restaurant_prep_time_min traffic_level area_type  \
# 0                   14                        18        medium     urban
# 1                   17                        36          high     urban
# 2                    9                        16           low     urban
# 3                    6                        29        medium  suburban
# 4                    9                        29           low     urban
#
#    delivery_time_minutes
# 0                     68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   distance_km               80000 non-null  float64
#  1   restaurant_rating         80000 non-null  float64
#  2   weather                   80000 non-null  object
#  3   time_of_day               80000 non-null  object
#  4   delivery_speed_kmph       80000 non-null  float64
#  5   active_orders_queue       80000 non-null  int64
#  6   restaurant_prep_time_min  80000 non-null  int64
#  7   traffic_level             80000 non-null  object
#  8   area_type                 80000 non-null  object
#  9   delivery_time_minutes     80000 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 6.1+ MB

# %%
True + True + False + True + False
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# distance_km                 0
# restaurant_rating           0
# weather                     0
# time_of_day                 0
# delivery_speed_kmph         0
# active_orders_queue         0
# restaurant_prep_time_min    0
# traffic_level               0
# area_type                   0
# delivery_time_minutes       0
# dtype: int64

# %%
df.active_orders_queue.sum()
# Out:
# np.int64(761318)

# %%
df.active_orders_queue.mean()
# Out:
# np.float64(9.516475)

# %%
df.active_orders_queue.median()
# Out:
# 10.0

# %%
df.active_orders_queue.mode()
# Out:
# 0    10
# Name: active_orders_queue, dtype: int64

# %%
df.active_orders_queue.min()
# Out:
# 0

# %%
df.active_orders_queue.max()
# Out:
# 19

# %%
df.dropna(inplace=True) #drop the row withc having missing value

# %%
df.head(10)
# Out:
#    distance_km  restaurant_rating weather time_of_day  delivery_speed_kmph  \
# 0         5.93                4.5  cloudy        peak                15.07
# 1        14.29                2.9   rainy        peak                21.00
# 2        11.11                4.9   sunny    off-peak                30.16
# 3         9.18                4.6  cloudy        peak                21.84
# 4         2.76                4.8   rainy    off-peak                36.26
# 5         2.76                3.2   sunny        peak                28.65
# 6         1.34                3.3   rainy        peak                15.86
# 7        13.06                3.7  cloudy        peak                12.89
# 8         9.22                3.1   sunny    off-peak                38.82
# 9        10.77                3.7   sunny        peak                31.37
#
#    active_orders_queue  restaurant_prep_time_min traffic_level area_type  \
# ...

# %%
df.weather.unique()
# Out:
# array(['cloudy', 'rainy', 'sunny'], dtype=object)

# %%
weather_dic = {
    'cloudy':0,
    'rainy': 1,
    'sunny': 2
}

# %%
df.weather = df.weather.map(weather_dic)

# %%
df.head()
# Out:
#    distance_km  restaurant_rating  weather time_of_day  delivery_speed_kmph  \
# 0         5.93                4.5        0        peak                15.07
# 1        14.29                2.9        1        peak                21.00
# 2        11.11                4.9        2    off-peak                30.16
# 3         9.18                4.6        0        peak                21.84
# 4         2.76                4.8        1    off-peak                36.26
#
#    active_orders_queue  restaurant_prep_time_min traffic_level area_type  \
# 0                   14                        18        medium     urban
# 1                   17                        36          high     urban
# 2                    9                        16           low     urban
# 3                    6                        29        medium  suburban
# 4                    9                        29           low     urban
#
#    delivery_time_minutes
# 0                     68
# ...

# %%
df.time_of_day.unique()
# Out:
# array(['peak', 'off-peak'], dtype=object)

# %%
time_dic = {
    'peak': 0,
    'off-peak': 1
}
df.time_of_day = df.time_of_day.map(time_dic)

# %%
df.head(2)
# Out:
#    distance_km  restaurant_rating  weather  time_of_day  delivery_speed_kmph  \
# 0         5.93                4.5        0            0                15.07
# 1        14.29                2.9        1            0                21.00
#
#    active_orders_queue  restaurant_prep_time_min traffic_level area_type  \
# 0                   14                        18        medium     urban
# 1                   17                        36          high     urban
#
#    delivery_time_minutes
# 0                     68
# 1                    112

# %%
df.traffic_level.unique()
# Out:
# array(['medium', 'high', 'low'], dtype=object)

# %%
traffic_dic = {
    'medium': 0,
    'high': 1,
    'low' : 2
}
df.traffic_level = df.traffic_level.map(traffic_dic)

# %%
df.head()
# Out:
#    distance_km  restaurant_rating  weather  time_of_day  delivery_speed_kmph  \
# 0         5.93                4.5        0            0                15.07
# 1        14.29                2.9        1            0                21.00
# 2        11.11                4.9        2            1                30.16
# 3         9.18                4.6        0            0                21.84
# 4         2.76                4.8        1            1                36.26
#
#    active_orders_queue  restaurant_prep_time_min  traffic_level area_type  \
# 0                   14                        18              0     urban
# 1                   17                        36              1     urban
# 2                    9                        16              2     urban
# 3                    6                        29              0  suburban
# 4                    9                        29              2     urban
#
#    delivery_time_minutes
# 0                     68
# ...

# %%
df.area_type.unique()
# Out:
# array(['urban', 'suburban', 'rural'], dtype=object)

# %%
area_dic = {
    'urban':0,
    'suburban':1,
    'rural': 2
}
df.area_type = df.area_type.map(area_dic)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   distance_km               80000 non-null  float64
#  1   restaurant_rating         80000 non-null  float64
#  2   weather                   80000 non-null  int64
#  3   time_of_day               80000 non-null  int64
#  4   delivery_speed_kmph       80000 non-null  float64
#  5   active_orders_queue       80000 non-null  int64
#  6   restaurant_prep_time_min  80000 non-null  int64
#  7   traffic_level             80000 non-null  int64
#  8   area_type                 80000 non-null  int64
#  9   delivery_time_minutes     80000 non-null  int64
# dtypes: float64(3), int64(7)
# memory usage: 6.1 MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (80000, 10)

# %%
x = df.drop(['delivery_time_minutes'], axis=1)
y = df.delivery_time_minutes

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 35.97094470190923

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 4.57945757203203

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9137061225555303
