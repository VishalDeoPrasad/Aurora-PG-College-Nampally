# %%
import pandas as pd
data = {
    'name': ['A', 'B', 'C', 'D'],
    'age': [12, 12, 45, 23],
    'city': ['Pune', 'Delhi', 'Hyd', 'Bgl']
}

df = pd.DataFrame(data)
df
# Out:
#   name  age   city
# 0    A   12   Pune
# 1    B   12  Delhi
# 2    C   45    Hyd
# 3    D   23    Bgl

# %%
df = pd.read_csv("/content/big_bazaar_sales.csv")
df
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0       BB1001     CUST583    Male   21  Ahmedabad        Household
# 1       BB1002     CUST766    Male   41  Bangalore        Furniture
# 2       BB1003     CUST285    Male   64      Surat        Groceries
# 3       BB1004     CUST381  Female   30     Nagpur      Electronics
# 4       BB1005     CUST979    Male   63       Pune           Sports
# ..         ...         ...     ...  ...        ...              ...
# 995     BB1996     CUST332  Female   36    Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36     Bhopal          Apparel
# 997     BB1998     CUST709    Male   55     Nagpur        Furniture
# 998     BB1999     CUST943    Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45      Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0          Doormat        10          224.45       2244.50           Cash
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Invoice_ID        1000 non-null   object
#  1   Customer_ID       1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   City              1000 non-null   object
#  5   Product_Category  1000 non-null   object
#  6   Product_Name      1000 non-null   object
#  7   Quantity          1000 non-null   int64
#  8   Price_Per_Unit    1000 non-null   float64
#  9   Total_Amount      1000 non-null   float64
#  10  Payment_Method    1000 non-null   object
#  11  Date_of_Purchase  1000 non-null   object
#  12  Discount_Percent  1000 non-null   int64
#  13  Final_Amount      1000 non-null   float64
#  14  Loyalty_Customer  1000 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#                Age     Quantity  Price_Per_Unit  Total_Amount  \
# count  1000.000000  1000.000000     1000.000000   1000.000000
# mean     41.508000     5.495000      260.870770   1443.521590
# std      13.549004     2.876847      137.790981   1142.772754
# min      18.000000     1.000000       21.590000     21.590000
# 25%      31.000000     3.000000      140.857500    484.245000
# 50%      41.000000     5.000000      254.690000   1118.790000
# 75%      53.000000     8.000000      387.065000   2167.740000
# max      65.000000    10.000000      499.790000   4904.700000
#
#        Discount_Percent  Final_Amount
# count       1000.000000   1000.000000
# mean           9.995000   1301.532830
# std            7.079908   1042.461948
# min            0.000000     19.430000
# 25%            5.000000    435.335000
# 50%           10.000000   1008.035000
# 75%           15.000000   1937.782500
# max           20.000000   4900.600000

# %%
df
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0       BB1001     CUST583    Male   21  Ahmedabad        Household
# 1       BB1002     CUST766    Male   41  Bangalore        Furniture
# 2       BB1003     CUST285    Male   64      Surat        Groceries
# 3       BB1004     CUST381  Female   30     Nagpur      Electronics
# 4       BB1005     CUST979    Male   63       Pune           Sports
# ..         ...         ...     ...  ...        ...              ...
# 995     BB1996     CUST332  Female   36    Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36     Bhopal          Apparel
# 997     BB1998     CUST709    Male   55     Nagpur        Furniture
# 998     BB1999     CUST943    Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45      Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0          Doormat        10          224.45       2244.50           Cash
# ...

# %%
df.head()
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
#
#   Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0       2025-05-06                10       2020.05               No
# ...

# %%
df.head(3)
# Out:
#   Invoice_ID Customer_ID Gender  Age       City Product_Category Product_Name  \
# 0     BB1001     CUST583   Male   21  Ahmedabad        Household      Doormat
# 1     BB1002     CUST766   Male   41  Bangalore        Furniture        Table
# 2     BB1003     CUST285   Male   64      Surat        Groceries       Paneer
#
#    Quantity  Price_Per_Unit  Total_Amount Payment_Method Date_of_Purchase  \
# 0        10          224.45       2244.50           Cash       2025-05-06
# 1         2          270.05        540.10    Credit Card       2025-04-04
# 2         9          436.59       3929.31            UPI       2024-12-01
#
#    Discount_Percent  Final_Amount Loyalty_Customer
# 0                10       2020.05               No
# 1                15        459.08              Yes
# 2                20       3143.45               No

# %%
df.head(6)
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
# 5     BB1006     CUST482    Male   32      Thane      Electronics
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
# 5   Power Bank         6          419.64       2517.84    Credit Card
#
# ...

# %%
df.tail()
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 995     BB1996     CUST332  Female   36    Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36     Bhopal          Apparel
# 997     BB1998     CUST709    Male   55     Nagpur        Furniture
# 998     BB1999     CUST943    Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45      Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 995     Board Game         7          474.27       3319.89            UPI
# 996       Leggings         7          437.77       3064.39         Wallet
# 997  Plastic Stool         1          278.20        278.20           Cash
# 998         Marker         8          260.94       2087.52         Wallet
# 999       Utensils         7           89.96        629.72           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# ...

# %%
df.tail(8)
# Out:
#     Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 992     BB1993     CUST340    Male   33      Nagpur           Beauty
# 993     BB1994     CUST504  Female   41      Jaipur           Sports
# 994     BB1995     CUST254    Male   43  Chandigarh        Furniture
# 995     BB1996     CUST332  Female   36     Lucknow     Toys & Games
# 996     BB1997     CUST327    Male   36      Bhopal          Apparel
# 997     BB1998     CUST709    Male   55      Nagpur        Furniture
# 998     BB1999     CUST943    Male   45   Hyderabad       Stationery
# 999     BB2000     CUST799    Male   45       Thane          Kitchen
#
#       Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 992      Body Wash         2           94.53        189.06            UPI
# 993      Dumbbells        10          441.41       4414.10    Credit Card
# 994       Bean Bag         3          448.43       1345.29           Cash
# ...

# %%
df.tail(2)
# Out:
#     Invoice_ID Customer_ID Gender  Age       City Product_Category  \
# 998     BB1999     CUST943   Male   45  Hyderabad       Stationery
# 999     BB2000     CUST799   Male   45      Thane          Kitchen
#
#     Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 998       Marker         8          260.94       2087.52         Wallet
# 999     Utensils         7           89.96        629.72           Cash
#
#     Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 998       2025-06-13                10       1878.77              Yes
# 999       2024-12-23                10        566.75               No

# %%
df.sample(10)
# Out:
#     Invoice_ID Customer_ID  Gender  Age           City Product_Category  \
# 109     BB1110     CUST634    Male   53     Chandigarh          Apparel
# 966     BB1967     CUST508  Female   26      Bangalore      Electronics
# 338     BB1339     CUST448    Male   40         Ranchi           Beauty
# 931     BB1932     CUST880  Female   38          Patna     Toys & Games
# 969     BB1970     CUST117    Male   29        Chennai      Electronics
# 681     BB1682     CUST284    Male   21          Patna          Kitchen
# 867     BB1868     CUST773    Male   22         Nagpur           Beauty
# 194     BB1195     CUST550    Male   36      Hyderabad          Apparel
# 921     BB1922     CUST388  Female   57  Visakhapatnam        Furniture
# 121     BB1122     CUST224    Male   50         Bhopal          Kitchen
#
#         Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 109      Track Pants         1          453.95        453.95    Credit Card
# ...

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.dtypes
# Out:
# Invoice_ID           object
# Customer_ID          object
# Gender               object
# Age                   int64
# City                 object
# Product_Category     object
# Product_Name         object
# Quantity              int64
# Price_Per_Unit      float64
# Total_Amount        float64
# Payment_Method       object
# Date_of_Purchase     object
# Discount_Percent      int64
# Final_Amount        float64
# Loyalty_Customer     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Customer_ID', 'Gender', 'Age', 'City',
#        'Product_Category', 'Product_Name', 'Quantity', 'Price_Per_Unit',
#        'Total_Amount', 'Payment_Method', 'Date_of_Purchase',
#        'Discount_Percent', 'Final_Amount', 'Loyalty_Customer'],
#       dtype='object')

# %%
df.head()
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
#
#   Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0       2025-05-06                10       2020.05               No
# ...

# %%
df.Product_Category
# Out:
# 0         Household
# 1         Furniture
# 2         Groceries
# 3       Electronics
# 4            Sports
#            ...
# 995    Toys & Games
# 996         Apparel
# 997       Furniture
# 998      Stationery
# 999         Kitchen
# Name: Product_Category, Length: 1000, dtype: object

# %%
df.Quantity

# %%
df['Quantity']
# Out:
# 0      10
# 1       2
# 2       9
# 3       6
# 4       2
#        ..
# 995     7
# 996     7
# 997     1
# 998     8
# 999     7
# Name: Quantity, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#   Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 0     BB1001     CUST583    Male   21  Ahmedabad        Household
# 1     BB1002     CUST766    Male   41  Bangalore        Furniture
# 2     BB1003     CUST285    Male   64      Surat        Groceries
# 3     BB1004     CUST381  Female   30     Nagpur      Electronics
# 4     BB1005     CUST979    Male   63       Pune           Sports
#
#   Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0      Doormat        10          224.45       2244.50           Cash
# 1        Table         2          270.05        540.10    Credit Card
# 2       Paneer         9          436.59       3929.31            UPI
# 3   Power Bank         6          254.36       1526.16         Wallet
# 4    Dumbbells         2          262.23        524.46         Wallet
#
#   Date_of_Purchase  Discount_Percent  Final_Amount Loyalty_Customer
# 0       2025-05-06                10       2020.05               No
# ...

# %%
df[['Product_Name','Quantity']]
# Out:
#       Product_Name  Quantity
# 0          Doormat        10
# 1            Table         2
# 2           Paneer         9
# 3       Power Bank         6
# 4        Dumbbells         2
# ..             ...       ...
# 995     Board Game         7
# 996       Leggings         7
# 997  Plastic Stool         1
# 998         Marker         8
# 999       Utensils         7
#
# [1000 rows x 2 columns]

# %%
df[['Product_Name','Quantity', 'Date_of_Purchase']]
# Out:
#       Product_Name  Quantity Date_of_Purchase
# 0          Doormat        10       2025-05-06
# 1            Table         2       2025-04-04
# 2           Paneer         9       2024-12-01
# 3       Power Bank         6       2024-10-03
# 4        Dumbbells         2       2025-01-04
# ..             ...       ...              ...
# 995     Board Game         7       2024-07-16
# 996       Leggings         7       2024-08-16
# 997  Plastic Stool         1       2025-06-06
# 998         Marker         8       2025-06-13
# 999       Utensils         7       2024-12-23
#
# [1000 rows x 3 columns]

# %%
df.head(10)
# Out:
#   Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 0     BB1001     CUST583    Male   21   Ahmedabad        Household
# 1     BB1002     CUST766    Male   41   Bangalore        Furniture
# 2     BB1003     CUST285    Male   64       Surat        Groceries
# 3     BB1004     CUST381  Female   30      Nagpur      Electronics
# 4     BB1005     CUST979    Male   63        Pune           Sports
# 5     BB1006     CUST482    Male   32       Thane      Electronics
# 6     BB1007     CUST435    Male   63      Indore           Beauty
# 7     BB1008     CUST427  Female   23     Kolkata       Stationery
# 8     BB1009     CUST935  Female   58       Delhi       Stationery
# 9     BB1010     CUST192    Male   36  Chandigarh        Household
#
#         Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0            Doormat        10          224.45       2244.50           Cash
# ...

# %%
cond = df.Age <= 20
df[cond]
# Out:
#     Invoice_ID Customer_ID  Gender  Age           City Product_Category  \
# 12      BB1013     CUST920  Female   19      Bangalore        Household
# 29      BB1030     CUST437  Female   19           Pune        Furniture
# 31      BB1032     CUST734  Female   18         Jaipur        Household
# 76      BB1077     CUST326    Male   19        Lucknow     Toys & Games
# 104     BB1105     CUST684  Female   20         Ranchi           Beauty
# 131     BB1132     CUST348  Female   18           Pune       Stationery
# 142     BB1143     CUST737    Male   20        Lucknow           Beauty
# 279     BB1280     CUST445  Female   20      Ahmedabad        Furniture
# 335     BB1336     CUST635  Female   20         Bhopal           Beauty
# 336     BB1337     CUST513    Male   19         Bhopal        Furniture
# 369     BB1370     CUST428  Female   19          Patna        Furniture
# 380     BB1381     CUST455  Female   18        Kolkata       Stationery
# ...

# %%
cond = df.Age > 60
df[cond]

# %%
cond = df.City == 'Bangalore'
df[cond]
# Out:
#     Invoice_ID Customer_ID  Gender  Age       City Product_Category  \
# 1       BB1002     CUST766    Male   41  Bangalore        Furniture
# 12      BB1013     CUST920  Female   19  Bangalore        Household
# 22      BB1023     CUST685  Female   42  Bangalore       Stationery
# 24      BB1025     CUST702  Female   63  Bangalore           Beauty
# 41      BB1042     CUST472    Male   33  Bangalore       Stationery
# 49      BB1050     CUST823  Female   49  Bangalore          Kitchen
# 63      BB1064     CUST354    Male   21  Bangalore          Apparel
# 66      BB1067     CUST949  Female   32  Bangalore           Beauty
# 71      BB1072     CUST109  Female   49  Bangalore       Stationery
# 74      BB1075     CUST994  Female   61  Bangalore      Electronics
# 81      BB1082     CUST815    Male   42  Bangalore        Household
# 116     BB1117     CUST755    Male   47  Bangalore       Stationery
# 138     BB1139     CUST135  Female   44  Bangalore        Household
# ...

# %%
df.head(10)
# Out:
#   Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 0     BB1001     CUST583    Male   21   Ahmedabad        Household
# 1     BB1002     CUST766    Male   41   Bangalore        Furniture
# 2     BB1003     CUST285    Male   64       Surat        Groceries
# 3     BB1004     CUST381  Female   30      Nagpur      Electronics
# 4     BB1005     CUST979    Male   63        Pune           Sports
# 5     BB1006     CUST482    Male   32       Thane      Electronics
# 6     BB1007     CUST435    Male   63      Indore           Beauty
# 7     BB1008     CUST427  Female   23     Kolkata       Stationery
# 8     BB1009     CUST935  Female   58       Delhi       Stationery
# 9     BB1010     CUST192    Male   36  Chandigarh        Household
#
#         Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# 0            Doormat        10          224.45       2244.50           Cash
# ...

# %%
df.sort_values(by='City')
# Out:
#     Invoice_ID Customer_ID  Gender  Age           City Product_Category  \
# 0       BB1001     CUST583    Male   21      Ahmedabad        Household
# 603     BB1604     CUST398    Male   36      Ahmedabad        Groceries
# 130     BB1131     CUST460    Male   47      Ahmedabad     Toys & Games
# 611     BB1612     CUST427    Male   40      Ahmedabad          Apparel
# 661     BB1662     CUST711  Female   21      Ahmedabad     Toys & Games
# ..         ...         ...     ...  ...            ...              ...
# 617     BB1618     CUST930    Male   43  Visakhapatnam     Toys & Games
# 575     BB1576     CUST364    Male   47  Visakhapatnam          Kitchen
# 339     BB1340     CUST966    Male   30  Visakhapatnam        Household
# 699     BB1700     CUST323    Male   41  Visakhapatnam           Sports
# 595     BB1596     CUST715    Male   33  Visakhapatnam      Electronics
#
#         Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# ...

# %%
df.sort_values(by='City', ascending=False)
# Out:
#     Invoice_ID Customer_ID  Gender  Age           City Product_Category  \
# 187     BB1188     CUST591    Male   32  Visakhapatnam        Household
# 800     BB1801     CUST174    Male   21  Visakhapatnam     Toys & Games
# 801     BB1802     CUST443  Female   21  Visakhapatnam      Electronics
# 886     BB1887     CUST173    Male   43  Visakhapatnam           Beauty
# 595     BB1596     CUST715    Male   33  Visakhapatnam      Electronics
# ..         ...         ...     ...  ...            ...              ...
# 838     BB1839     CUST256    Male   20      Ahmedabad        Furniture
# 102     BB1103     CUST504    Male   42      Ahmedabad        Groceries
# 279     BB1280     CUST445  Female   20      Ahmedabad        Furniture
# 107     BB1108     CUST385    Male   24      Ahmedabad       Stationery
# 0       BB1001     CUST583    Male   21      Ahmedabad        Household
#
#         Product_Name  Quantity  Price_Per_Unit  Total_Amount Payment_Method  \
# ...

# %%
df.sort_values(by='Age')
# Out:
#     Invoice_ID Customer_ID  Gender  Age        City Product_Category  \
# 518     BB1519     CUST868  Female   18  Chandigarh        Groceries
# 477     BB1478     CUST163  Female   18   Bangalore          Kitchen
# 685     BB1686     CUST776    Male   18   Ahmedabad        Furniture
# 715     BB1716     CUST661    Male   18     Lucknow        Furniture
# 723     BB1724     CUST347  Female   18       Thane       Stationery
# ..         ...         ...     ...  ...         ...              ...
# 748     BB1749     CUST102  Female   65     Kolkata        Household
# 127     BB1128     CUST751  Female   65      Nagpur          Apparel
# 824     BB1825     CUST833  Female   65      Bhopal          Kitchen
# 48      BB1049     CUST857  Female   65      Mumbai          Apparel
# 721     BB1722     CUST471    Male   65    Vadodara          Kitchen
#
#            Product_Name  Quantity  Price_Per_Unit  Total_Amount  \
# 518               Bread         4          129.67        518.68
# ...
