# %%
import matplotlib.pyplot as plt

# %%
year = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2024]
sales = [20000, 30000, 35000, 37000, 40000, 41000, 50000, 60000, 70000, 80000, 90000, 150000, 250000, 20000, 30000, 35000,]

# %%
plt.plot(year, sales)

# %%
size = ['S', 'M', 'L', 'XL']
value = [13, 12, 4, 7]

# %%
plt.bar(size, value)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(size, value)
# Out:
# <BarContainer object of 4 artists>

# %%
age = [12,18,19,45,43,56,34,67,34,67,34,67,12,56,40,32,56,34,23,56]
plt.hist(age)
# Out:
# (array([2., 2., 1., 1., 4., 2., 1., 0., 4., 3.]),
#  array([12. , 17.5, 23. , 28.5, 34. , 39.5, 45. , 50.5, 56. , 61.5, 67. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
age = np.random.randint(1, 100, 50)
plt.hist(age)
# Out:
# (array([9., 4., 3., 5., 3., 4., 9., 4., 4., 5.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)
